# %%
program_text = """

void main(int ars, char argv[])
{
    int i;    //init
    float f;
    string s;
    bool b;
    
    hex h;
    oct o;
    bin bit;
    fixed fix;
    
    read(s);   //read write
    print( s );
    
    i = 06;    //assign
    i =0x7;
    i= 0b01;
    i=6;
    f = 0.50;
    
    if(i == 6  or i==5 and i!= 6 and i<=5)  //condition
    {
        i = 5;
    }
    else /* I want multicomment here
    and noone can stop me 
    do this */
    {
        i = 6;
    }
    
    while(i < 10) //cycle
    {
        i = i + 1;
    }
    
    i = 08;
    i = 0x1g2;
    i = 0b02;
    i = 0abc;
    ias& = 12;
    i = 12abc;
}

"""

dictionary = {
    "void": "function_type",
    "int": "type",
    "float": "type",
    "string": "type",
    "char": "type",
    "bool":  "type",
    "hex": "type",
    "oct": "type",
    "bin": "type",
    "fixed": "type",
    
    "main": "entry_point",
    "(": "bracket_smooth_l",
    ")": "bracket_smooth_r",
    "{": "bracket_curve_l",
    "}": "bracket_curve_r",
    "[": "bracket_rect_l",
    "]": "bracket_rect_r",
    ";": "divider",
    "read": "reader",
    "print": "printer",
    "==": "comparsion",
    "<=": "comparsion",
    ">=": "comparsion",
    "=": "assign",
    "!": "bool not",
    "!=": "comparsion",
    "<": "comparsion",
    ">": "comparsion",
    "+": "math_symbol",
    "-": "math_symbol",
    "*": "math_symbol",
    "//": "comment_start",
    "/": "math_symbol",
    "%": "math_symbol",
    ",": "comma",
    " ": "separator",
    "\n": "new_line",
    
    "if": "condition",
    "else": "condition_else",
    "while": "cycle"
}

# %%
LETTERS = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ"
SYMBOLS = "(){}[];=<>!+-*/%, "
NUMBERS = "0123456789"
STOP_POINTS = " (){}[];=<>!+-*/%,\n"

BIN = "01"
OCT = "01234567"
HEX = "0123456789abcdefABCDEF"

HEX_START = "x"
BIN_START = "b"

POINT = "."

ROW_NAME = "Row "
ROW_COL_DIVIDER_NAME = " / "
COLUMN_NAME = "Col "

WORD_TO_TYPE_DELIMER = " - "
ERROR_NAME = "ERR"
COMMENT_NAME = "Comment"
ID_NAME = "ID"
HEX_NAME = "HEX"
OCT_NAME = "OCT"
BIN_NAME = "BIN"
DEC_NAME = "INT"
FLOAT_NAME = "FLOAT"

# %%
class Lexer(object):
    
    def __init__(self, program_text):
        self.text = program_text + "\n"
        self.list = []
    
        
    def run(self, show_states = False, show_spaces = False):
        
        def state_error(symbol, word, row, column):
            if symbol in STOP_POINTS:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + ERROR_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            else:
                return state_error
            
        def state_unary_stop_symbol(symbol, word, row, column):
            if dictionary.get(word[0], False):
                if word[0] == " " and not show_spaces:
                    pass
                else:    
                    self.list.append([word[0], WORD_TO_TYPE_DELIMER + dictionary[word[0]], ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
            word[0] = ""
            return state_start(symbol, word, row, column)
        
        def state_undefined_stop_symbol(symbol, word, row, column):
            if symbol == "=":
                return state_dual_stop_symbol
            else:
                if dictionary.get(word[0], False):
                    self.list.append([word[0], WORD_TO_TYPE_DELIMER + dictionary[word[0]], ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_dual_stop_symbol(symbol, word, row, column):
            if dictionary.get(word[0], False):
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + dictionary[word[0]], ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
            word[0] = ""
            return state_start(symbol, word, row, column)
        
        def state_slash_symbol(symbol, word, row, column):
            if symbol == "/":
                return state_comment
            elif symbol == "*":
                return state_multi_comment
            else:
                if dictionary.get(word[0], False):
                    self.list.append([word[0], WORD_TO_TYPE_DELIMER + dictionary[word[0]], ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
        
        def state_comment(symbol, word, row, column):
            if symbol == "\n":
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + COMMENT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            else:
                return state_comment
            
        def state_multi_comment(symbol, word, row, column):
            if symbol == "*":
                return state_multi_comment_exit
            else:
                return state_multi_comment
            
        def state_multi_comment_exit(symbol, word, row, column):
            if symbol == "/":
                self.list.append([word[0] + "/", WORD_TO_TYPE_DELIMER + COMMENT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start
            else:
                return state_multi_comment
            
                
        def state_identifier(symbol, word, row, column):   
            if symbol in LETTERS + NUMBERS + "_":
                return state_identifier
            else:
                if dictionary.get(word[0], False):
                    self.list.append([word[0], WORD_TO_TYPE_DELIMER + dictionary[word[0]], ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                else:
                    self.list.append([word[0], WORD_TO_TYPE_DELIMER + ID_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_hex_number(symbol, word, row, column):
            if symbol in HEX:
                return state_hex_number
            elif symbol in NUMBERS + LETTERS:
                return state_error(symbol, word, row, column)
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + HEX_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_bin_number(symbol, word, row, column):
            if symbol in BIN:
                return state_bin_number
            elif symbol in NUMBERS + LETTERS:
                return state_error(symbol, word, row, column)
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + BIN_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_oct_number(symbol, word, row, column):
            if symbol in OCT:
                return state_oct_number
            elif symbol in NUMBERS + LETTERS:
                return state_error(symbol, word, row, column)
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + OCT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_float(symbol, word, row, column):
            if symbol in NUMBERS:
                return state_float
            elif symbol in "eE":
                return state_float_exponent
            elif symbol in LETTERS:
                return state_error(symbol, word, row, column) 
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + FLOAT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_undefined_float(symbol, word, row, column):
            if symbol in NUMBERS:
                return state_float
            elif symbol in LETTERS:
                return state_error(symbol, word, row, column) 
            else:
                return state_error(symbol, word, row, column)
            
        def state_float_exponent(symbol, word, row, column):
            if symbol in "+-":
                return state_float_exponent_sign
            else:
                return state_error
            
        def state_float_exponent_sign(symbol, word, row, column):
            if symbol in "123456789":
                return state_float_exponent_numbers
            elif symbol in "0":
                return state_float_exponent_zero
            else:
                return state_error
            
        def state_float_exponent_numbers(symbol, word, row, column):
            if symbol in "0123456789":
                return state_float_exponent_numbers
            elif symbol in LETTERS:
                return state_error(symbol, word, row, column) 
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + FLOAT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_float_exponent_zero(symbol, word, row, column):
            if symbol in LETTERS + NUMBERS:
                return state_error(symbol, word, row, column) 
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + FLOAT_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
        
        def state_any_number(symbol, word, row, column):
            if symbol == HEX_START:
                return state_hex_number
            elif symbol == BIN_START:
                return state_bin_number
            elif symbol in OCT:
                return state_oct_number
            elif symbol == POINT:
                return state_float
            elif symbol in NUMBERS + LETTERS:
                return state_error(symbol, word, row, column)
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + DEC_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
            
        def state_int_or_float(symbol, word, row, column):
            if symbol in NUMBERS:
                return state_int_or_float
            elif symbol == POINT:
                return state_float
            elif symbol in LETTERS:
                return state_error(symbol, word, row, column)
            else:
                self.list.append([word[0], WORD_TO_TYPE_DELIMER + DEC_NAME, ROW_NAME + str(row) + ROW_COL_DIVIDER_NAME + COLUMN_NAME + str(column)])
                word[0] = ""
                return state_start(symbol, word, row, column)
        
        def state_start(symbol, word, row, column):
            if symbol in LETTERS:
                return state_identifier
            elif symbol == "/":
                return state_slash_symbol
            elif symbol in "<>!=":
                return state_undefined_stop_symbol
            elif symbol in "(){}[];+-*%, \n":
                return state_unary_stop_symbol
            elif symbol in "123456789":
                return state_int_or_float
            elif symbol == "0":
                return state_any_number
            elif symbol == ".":
                return state_undefined_float
            else:
                return state_error
        
        state = state_start
        word = [""]
    
        row = 0
        column = -1
        last_symbol = ""
        for i in self.text:
            new_state = state(i, word, row, column)
            
            if show_states:
                print(new_state, i)
            
            word[0] = word[0] + i
            
            state = new_state
            
            if last_symbol == "\n":
                row = row + 1
                column = 0
            else:
                column = column + 1
                
            last_symbol = i
            
            
    def show(self):
        for i in self.list:
            print(i)

# %%
lex = Lexer(program_text)
lex.run(show_states = False, show_spaces = False)
lex.show()
# Out:
# ['\n', ' - new_line', 'Row 0 / Col 0']
# ['\n', ' - new_line', 'Row 1 / Col 0']
# ['void', ' - function_type', 'Row 2 / Col 3']
# ['main', ' - entry_point', 'Row 2 / Col 8']
# ['(', ' - bracket_smooth_l', 'Row 2 / Col 9']
# ['int', ' - type', 'Row 2 / Col 12']
# ['ars', ' - ID', 'Row 2 / Col 16']
# [',', ' - comma', 'Row 2 / Col 17']
# ['char', ' - type', 'Row 2 / Col 22']
# ['argv', ' - ID', 'Row 2 / Col 27']
# ['[', ' - bracket_rect_l', 'Row 2 / Col 28']
# [']', ' - bracket_rect_r', 'Row 2 / Col 29']
# [')', ' - bracket_smooth_r', 'Row 2 / Col 30']
# ['\n', ' - new_line', 'Row 2 / Col 31']
# ['{', ' - bracket_curve_l', 'Row 3 / Col 0']
# ['\n', ' - new_line', 'Row 3 / Col 1']
# ['int', ' - type', 'Row 4 / Col 6']
# ['i', ' - ID', 'Row 4 / Col 8']
# [';', ' - divider', 'Row 4 / Col 9']
# ['//init', ' - Comment', 'Row 4 / Col 19']
# ['\n', ' - new_line', 'Row 4 / Col 20']
# ['float', ' - type', 'Row 5 / Col 8']
# ['f', ' - ID', 'Row 5 / Col 10']
# [';', ' - divider', 'Row 5 / Col 11']
# ['\n', ' - new_line', 'Row 5 / Col 12']
# ['string', ' - type', 'Row 6 / Col 9']
# ['s', ' - ID', 'Row 6 / Col 11']
# [';', ' - divider', 'Row 6 / Col 12']
# ['\n', ' - new_line', 'Row 6 / Col 13']
# ['bool', ' - type', 'Row 7 / Col 7']
# ['b', ' - ID', 'Row 7 / Col 9']
# [';', ' - divider', 'Row 7 / Col 10']
# ['\n', ' - new_line', 'Row 7 / Col 11']
# ['\n', ' - new_line', 'Row 8 / Col 4']
# ['hex', ' - type', 'Row 9 / Col 6']
# ['h', ' - ID', 'Row 9 / Col 8']
# [';', ' - divider', 'Row 9 / Col 9']
# ['\n', ' - new_line', 'Row 9 / Col 10']
# ['oct', ' - type', 'Row 10 / Col 6']
# ['o', ' - ID', 'Row 10 / Col 8']
# [';', ' - divider', 'Row 10 / Col 9']
# ['\n', ' - new_line', 'Row 10 / Col 10']
# ['bin', ' - type', 'Row 11 / Col 6']
# ['bit', ' - ID', 'Row 11 / Col 10']
# [';', ' - divider', 'Row 11 / Col 11']
# ['\n', ' - new_line', 'Row 11 / Col 12']
# ['fixed', ' - type', 'Row 12 / Col 8']
# ['fix', ' - ID', 'Row 12 / Col 12']
# [';', ' - divider', 'Row 12 / Col 13']
# ['\n', ' - new_line', 'Row 12 / Col 14']
# ['\n', ' - new_line', 'Row 13 / Col 4']
# ['read', ' - reader', 'Row 14 / Col 7']
# ['(', ' - bracket_smooth_l', 'Row 14 / Col 8']
# ['s', ' - ID', 'Row 14 / Col 9']
# [')', ' - bracket_smooth_r', 'Row 14 / Col 10']
# [';', ' - divider', 'Row 14 / Col 11']
# ['//read write', ' - Comment', 'Row 14 / Col 26']
# ['\n', ' - new_line', 'Row 14 / Col 27']
# ['print', ' - printer', 'Row 15 / Col 8']
# ['(', ' - bracket_smooth_l', 'Row 15 / Col 9']
# ['s', ' - ID', 'Row 15 / Col 11']
# [')', ' - bracket_smooth_r', 'Row 15 / Col 13']
# [';', ' - divider', 'Row 15 / Col 14']
# ['\n', ' - new_line', 'Row 15 / Col 15']
# ['\n', ' - new_line', 'Row 16 / Col 4']
# ['i', ' - ID', 'Row 17 / Col 4']
# ['=', ' - assign', 'Row 17 / Col 6']
# ['06', ' - OCT', 'Row 17 / Col 9']
# [';', ' - divider', 'Row 17 / Col 10']
# ['//assign', ' - Comment', 'Row 17 / Col 22']
# ['\n', ' - new_line', 'Row 17 / Col 23']
# ['i', ' - ID', 'Row 18 / Col 4']
# ['=', ' - assign', 'Row 18 / Col 6']
# ['0x7', ' - HEX', 'Row 18 / Col 9']
# [';', ' - divider', 'Row 18 / Col 10']
# ['\n', ' - new_line', 'Row 18 / Col 11']
# ['i', ' - ID', 'Row 19 / Col 4']
# ['=', ' - assign', 'Row 19 / Col 5']
# ['0b01', ' - BIN', 'Row 19 / Col 10']
# [';', ' - divider', 'Row 19 / Col 11']
# ['\n', ' - new_line', 'Row 19 / Col 12']
# ['i', ' - ID', 'Row 20 / Col 4']
# ['=', ' - assign', 'Row 20 / Col 5']
# ['6', ' - INT', 'Row 20 / Col 6']
# [';', ' - divider', 'Row 20 / Col 7']
# ['\n', ' - new_line', 'Row 20 / Col 8']
# ['f', ' - ID', 'Row 21 / Col 4']
# ['=', ' - assign', 'Row 21 / Col 6']
# ['0.50', ' - FLOAT', 'Row 21 / Col 11']
# [';', ' - divider', 'Row 21 / Col 12']
# ['\n', ' - new_line', 'Row 21 / Col 13']
# ['\n', ' - new_line', 'Row 22 / Col 4']
# ['if', ' - condition', 'Row 23 / Col 5']
# ['(', ' - bracket_smooth_l', 'Row 23 / Col 6']
# ['i', ' - ID', 'Row 23 / Col 7']
# ['==', ' - comparsion', 'Row 23 / Col 10']
# ['6', ' - INT', 'Row 23 / Col 12']
# ['or', ' - ID', 'Row 23 / Col 16']
# ['i', ' - ID', 'Row 23 / Col 18']
# ['==', ' - comparsion', 'Row 23 / Col 20']
# ['5', ' - INT', 'Row 23 / Col 21']
# ['and', ' - ID', 'Row 23 / Col 25']
# ['i', ' - ID', 'Row 23 / Col 27']
# ['!=', ' - comparsion', 'Row 23 / Col 29']
# ['6', ' - INT', 'Row 23 / Col 31']
# ['and', ' - ID', 'Row 23 / Col 35']
# ['i', ' - ID', 'Row 23 / Col 37']
# ['<=', ' - comparsion', 'Row 23 / Col 39']
# ['5', ' - INT', 'Row 23 / Col 40']
# [')', ' - bracket_smooth_r', 'Row 23 / Col 41']
# ['//condition', ' - Comment', 'Row 23 / Col 54']
# ['\n', ' - new_line', 'Row 23 / Col 55']
# ['{', ' - bracket_curve_l', 'Row 24 / Col 4']
# ['\n', ' - new_line', 'Row 24 / Col 5']
# ['i', ' - ID', 'Row 25 / Col 8']
# ['=', ' - assign', 'Row 25 / Col 10']
# ['5', ' - INT', 'Row 25 / Col 12']
# [';', ' - divider', 'Row 25 / Col 13']
# ['\n', ' - new_line', 'Row 25 / Col 14']
# ['}', ' - bracket_curve_r', 'Row 26 / Col 4']
# ['\n', ' - new_line', 'Row 26 / Col 5']
# ['else', ' - condition_else', 'Row 27 / Col 7']
# ['/* I want multicomment here\n    and noone can stop me \n    do this */', ' - Comment', 'Row 29 / Col 12']
# ['{', ' - bracket_curve_l', 'Row 30 / Col 4']
# ['\n', ' - new_line', 'Row 30 / Col 5']
# ['i', ' - ID', 'Row 31 / Col 8']
# ['=', ' - assign', 'Row 31 / Col 10']
# ['6', ' - INT', 'Row 31 / Col 12']
# [';', ' - divider', 'Row 31 / Col 13']
# ['\n', ' - new_line', 'Row 31 / Col 14']
# ['}', ' - bracket_curve_r', 'Row 32 / Col 4']
# ['\n', ' - new_line', 'Row 32 / Col 5']
# ['\n', ' - new_line', 'Row 33 / Col 4']
# ['while', ' - cycle', 'Row 34 / Col 8']
# ['(', ' - bracket_smooth_l', 'Row 34 / Col 9']
# ['i', ' - ID', 'Row 34 / Col 10']
# ['<', ' - comparsion', 'Row 34 / Col 12']
# ['10', ' - INT', 'Row 34 / Col 15']
# [')', ' - bracket_smooth_r', 'Row 34 / Col 16']
# ['//cycle', ' - Comment', 'Row 34 / Col 24']
# ['\n', ' - new_line', 'Row 34 / Col 25']
# ['{', ' - bracket_curve_l', 'Row 35 / Col 4']
# ['\n', ' - new_line', 'Row 35 / Col 5']
# ['i', ' - ID', 'Row 36 / Col 8']
# ['=', ' - assign', 'Row 36 / Col 10']
# ['i', ' - ID', 'Row 36 / Col 12']
# ['+', ' - math_symbol', 'Row 36 / Col 14']
# ['1', ' - INT', 'Row 36 / Col 16']
# [';', ' - divider', 'Row 36 / Col 17']
# ['\n', ' - new_line', 'Row 36 / Col 18']
# ['}', ' - bracket_curve_r', 'Row 37 / Col 4']
# ['\n', ' - new_line', 'Row 37 / Col 5']
# ['\n', ' - new_line', 'Row 38 / Col 4']
# ['i', ' - ID', 'Row 39 / Col 4']
# ['=', ' - assign', 'Row 39 / Col 6']
# ['08', ' - ERR', 'Row 39 / Col 9']
# [';', ' - divider', 'Row 39 / Col 10']
# ['\n', ' - new_line', 'Row 39 / Col 11']
# ['i', ' - ID', 'Row 40 / Col 4']
# ['=', ' - assign', 'Row 40 / Col 6']
# ['0x1g2', ' - ERR', 'Row 40 / Col 12']
# [';', ' - divider', 'Row 40 / Col 13']
# ['\n', ' - new_line', 'Row 40 / Col 14']
# ['i', ' - ID', 'Row 41 / Col 4']
# ['=', ' - assign', 'Row 41 / Col 6']
# ['0b02', ' - ERR', 'Row 41 / Col 11']
# [';', ' - divider', 'Row 41 / Col 12']
# ['\n', ' - new_line', 'Row 41 / Col 13']
# ['i', ' - ID', 'Row 42 / Col 4']
# ['=', ' - assign', 'Row 42 / Col 6']
# ['0abc', ' - ERR', 'Row 42 / Col 11']
# [';', ' - divider', 'Row 42 / Col 12']
# ['\n', ' - new_line', 'Row 42 / Col 13']
# ['ias', ' - ID', 'Row 43 / Col 6']
# ['&', ' - ERR', 'Row 43 / Col 7']
# ['=', ' - assign', 'Row 43 / Col 9']
# ['12', ' - INT', 'Row 43 / Col 12']
# [';', ' - divider', 'Row 43 / Col 13']
# ['\n', ' - new_line', 'Row 43 / Col 14']
# ['i', ' - ID', 'Row 44 / Col 4']
# ['=', ' - assign', 'Row 44 / Col 6']
# ['12abc', ' - ERR', 'Row 44 / Col 12']
# [';', ' - divider', 'Row 44 / Col 13']
# ['\n', ' - new_line', 'Row 44 / Col 14']
# ['}', ' - bracket_curve_r', 'Row 45 / Col 0']
# ['\n', ' - new_line', 'Row 45 / Col 1']
# ['\n', ' - new_line', 'Row 46 / Col 0']

# %%
lex = Lexer("iden!ifier")
lex.run()
lex.show()
# Out:
# ['iden', ' - ID', 'Row 0 / Col 3']
# ['!', ' - bool not', 'Row 0 / Col 4']
# ['ifier', ' - ID', 'Row 0 / Col 9']

# %%
lex = Lexer(".278392\n2.432\n8741.")
lex.run()
lex.show()
# Out:
# ['.278392', ' - FLOAT', 'Row 0 / Col 6']
# ['\n', ' - new_line', 'Row 0 / Col 7']
# ['2.432', ' - FLOAT', 'Row 1 / Col 4']
# ['\n', ' - new_line', 'Row 1 / Col 5']
# ['8741.', ' - FLOAT', 'Row 2 / Col 4']

# %%
lex = Lexer("3.14e+74\n 3.14e+0\n 3.14e-1222\n 3.14e-\n 3.14e+12.\n 3.14e+12a\n .\n")
lex.run()
lex.show()
# Out:
# ['3.14e+74', ' - FLOAT', 'Row 0 / Col 7']
# ['\n', ' - new_line', 'Row 0 / Col 8']
# ['3.14e+0', ' - FLOAT', 'Row 1 / Col 7']
# ['\n', ' - new_line', 'Row 1 / Col 8']
# ['3.14e-1222', ' - FLOAT', 'Row 2 / Col 10']
# ['\n', ' - new_line', 'Row 2 / Col 11']
# ['3.14e-\n', ' - ERR', 'Row 3 / Col 7']
# ['3.14e+12', ' - FLOAT', 'Row 4 / Col 8']
# ['.', ' - ERR', 'Row 4 / Col 9']
# ['\n', ' - new_line', 'Row 4 / Col 10']
# ['3.14e+12a', ' - ERR', 'Row 5 / Col 9']
# ['\n', ' - new_line', 'Row 5 / Col 10']
# ['.', ' - ERR', 'Row 6 / Col 1']
# ['\n', ' - new_line', 'Row 6 / Col 2']

# %%
program = """void main()
{
    int i = 0.15e+10; //init
    if( i<= 10){print(10);}
}
"""

lex = Lexer(program)
lex.run()
lex.show()
# Out:
# ['\n', ' - new_line', 'Row 0 / Col 0']
# ['void', ' - function_type', 'Row 1 / Col 3']
# ['main', ' - entry_point', 'Row 1 / Col 8']
# ['(', ' - bracket_smooth_l', 'Row 1 / Col 9']
# [')', ' - bracket_smooth_r', 'Row 1 / Col 10']
# ['\n', ' - new_line', 'Row 1 / Col 11']
# ['{', ' - bracket_curve_l', 'Row 2 / Col 0']
# ['\n', ' - new_line', 'Row 2 / Col 1']
# ['int', ' - type', 'Row 3 / Col 6']
# ['i', ' - ID', 'Row 3 / Col 8']
# ['=', ' - assign', 'Row 3 / Col 10']
# ['0.15e+10', ' - FLOAT', 'Row 3 / Col 19']
# [';', ' - divider', 'Row 3 / Col 20']
# ['//init', ' - Comment', 'Row 3 / Col 27']
# ['\n', ' - new_line', 'Row 3 / Col 28']
# ['if', ' - condition', 'Row 4 / Col 5']
# ['(', ' - bracket_smooth_l', 'Row 4 / Col 6']
# ['i', ' - ID', 'Row 4 / Col 8']
# ['<=', ' - comparsion', 'Row 4 / Col 10']
# ['10', ' - INT', 'Row 4 / Col 13']
# [')', ' - bracket_smooth_r', 'Row 4 / Col 14']
# ['{', ' - bracket_curve_l', 'Row 4 / Col 15']
# ['print', ' - printer', 'Row 4 / Col 20']
# ['(', ' - bracket_smooth_l', 'Row 4 / Col 21']
# ['10', ' - INT', 'Row 4 / Col 23']
# [')', ' - bracket_smooth_r', 'Row 4 / Col 24']
# [';', ' - divider', 'Row 4 / Col 25']
# ['}', ' - bracket_curve_r', 'Row 4 / Col 26']
# ['\n', ' - new_line', 'Row 4 / Col 27']
# ['}', ' - bracket_curve_r', 'Row 5 / Col 0']
# ['\n', ' - new_line', 'Row 5 / Col 1']
